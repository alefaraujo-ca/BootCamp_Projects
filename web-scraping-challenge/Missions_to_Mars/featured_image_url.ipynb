# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import pandas as pd

# %%
executable_path = {'executable_path':'chromedriver.exe'}

browser = Browser('chrome', **executable_path, headless=False)

url='https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)

# %%
html = browser.html
soup = bs(html, 'lxml')
#table=soup.find('div',class_='grid_layout')
#rows = soup.find_all('li')

# %%
image = soup.find("img", class_="thumb")["src"]
print(image)
# Out:
# /spaceimages/images/wallpaper/PIA23633-640x350.jpg

# %%
featured_image_url = 'https://www.jpl.nasa.gov/' + image
print(featured_image_url)
# Out:
# https://www.jpl.nasa.gov//spaceimages/images/wallpaper/PIA23633-640x350.jpg

# %%
table=soup.find('ul',class_='articles')

# %%
table.find_all('li')
# Out:
# [<li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Mamers Valles. The channel is nearly 1000 km long (600 miles)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23633_hires.jpg" data-link="/spaceimages/details.php?id=PIA23633" data-thumbnail="/spaceimages/images/wallpaper/PIA23633-640x350.jpg" data-title="Mamers Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 8, 2020</h3>
#  <div class="item_tease_overlay">Mamers Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Mamers Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23633-640x350.jpg" title="Mamers Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 8, 2020</div>
#  <div class="content_title">
#  										  Mamers Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Mamers Valles. The channel is nearly 1000 km long (600 miles).
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of a graben that is part of Nili Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23632_hires.jpg" data-link="/spaceimages/details.php?id=PIA23632" data-thumbnail="/spaceimages/images/wallpaper/PIA23632-640x350.jpg" data-title="Nili Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 7, 2020</h3>
#  <div class="item_tease_overlay">Nili Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Nili Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23632-640x350.jpg" title="Nili Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 7, 2020</div>
#  <div class="content_title">
#  										  Nili Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of a graben that is part of Nili Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a sinuous channel, Tinto Vallis." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23631_hires.jpg" data-link="/spaceimages/details.php?id=PIA23631" data-thumbnail="/spaceimages/images/wallpaper/PIA23631-640x350.jpg" data-title="Tinto Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 6, 2020</h3>
#  <div class="item_tease_overlay">Tinto Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Tinto Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23631-640x350.jpg" title="Tinto Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 6, 2020</div>
#  <div class="content_title">
#  										  Tinto Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a sinuous channel, Tinto Vallis.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of Kaiser Crater. Kaiser Crater is 207 km (129 miles) in diameter and is located in Noachis Terra west of Hellas Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23630_hires.jpg" data-link="/spaceimages/details.php?id=PIA23630" data-thumbnail="/spaceimages/images/wallpaper/PIA23630-640x350.jpg" data-title="Kaiser Crater Dunes - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 3, 2020</h3>
#  <div class="item_tease_overlay">Kaiser Crater Dunes - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Kaiser Crater Dunes - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23630-640x350.jpg" title="Kaiser Crater Dunes - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 3, 2020</div>
#  <div class="content_title">
#  										  Kaiser Crater Dunes - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the floor of Kaiser Crater. Kaiser Crater is 207 km (129 miles) in diameter and is located in Noachis Terra west of Hellas Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows sand dunes on the floor of Hale Crater, located north of Argyre Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23629_hires.jpg" data-link="/spaceimages/details.php?id=PIA23629" data-thumbnail="/spaceimages/images/wallpaper/PIA23629-640x350.jpg" data-title="Hale Crater Dunes - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 2, 2020</h3>
#  <div class="item_tease_overlay">Hale Crater Dunes - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hale Crater Dunes - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23629-640x350.jpg" title="Hale Crater Dunes - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 2, 2020</div>
#  <div class="content_title">
#  										  Hale Crater Dunes - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows sand dunes on the floor of Hale Crater, located north of Argyre Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows sand dunes on the floor of Sumgin Crater. The crater is located in Noachis Terra north of Argyre Planitia." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23628_hires.jpg" data-link="/spaceimages/details.php?id=PIA23628" data-thumbnail="/spaceimages/images/wallpaper/PIA23628-640x350.jpg" data-title="Sumgin Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">January 1, 2020</h3>
#  <div class="item_tease_overlay">Sumgin Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Sumgin Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23628-640x350.jpg" title="Sumgin Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">January 1, 2020</div>
#  <div class="content_title">
#  										  Sumgin Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows sand dunes on the floor of Sumgin Crater. The crater is located in Noachis Terra north of Argyre Planitia.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Juventae Chasma, located north of Valles Marineris." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23627_hires.jpg" data-link="/spaceimages/details.php?id=PIA23627" data-thumbnail="/spaceimages/images/wallpaper/PIA23627-640x350.jpg" data-title="Juventae Chasma - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 31, 2019</h3>
#  <div class="item_tease_overlay">Juventae Chasma - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Juventae Chasma - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23627-640x350.jpg" title="Juventae Chasma - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 31, 2019</div>
#  <div class="content_title">
#  										  Juventae Chasma - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Juventae Chasma, located north of Valles Marineris.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of Hale Crater and the elongate axis of the central peak mountains." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23626_hires.jpg" data-link="/spaceimages/details.php?id=PIA23626" data-thumbnail="/spaceimages/images/wallpaper/PIA23626-640x350.jpg" data-title="Hale Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 30, 2019</h3>
#  <div class="item_tease_overlay">Hale Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hale Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23626-640x350.jpg" title="Hale Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 30, 2019</div>
#  <div class="content_title">
#  										  Hale Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the floor of Hale Crater and the elongate axis of the central peak mountains.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows pits on the south polar cap. The terrain has the appearance of a slice of swiss cheese, giving rise to the informal name." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23615_hires.jpg" data-link="/spaceimages/details.php?id=PIA23615" data-thumbnail="/spaceimages/images/wallpaper/PIA23615-640x350.jpg" data-title="Swiss Cheese - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 27, 2019</h3>
#  <div class="item_tease_overlay">Swiss Cheese - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Swiss Cheese - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23615-640x350.jpg" title="Swiss Cheese - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 27, 2019</div>
#  <div class="content_title">
#  										  Swiss Cheese - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows pits on the south polar cap. The terrain has the appearance of a slice of swiss cheese, giving rise to the informal name.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the south polar cap. The cap was created over millions of years with deposition of ice and dust during different seasons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23614_hires.jpg" data-link="/spaceimages/details.php?id=PIA23614" data-thumbnail="/spaceimages/images/wallpaper/PIA23614-640x350.jpg" data-title="South Polar Ice - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 26, 2019</h3>
#  <div class="item_tease_overlay">South Polar Ice - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="South Polar Ice - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23614-640x350.jpg" title="South Polar Ice - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 26, 2019</div>
#  <div class="content_title">
#  										  South Polar Ice - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the south polar cap. The cap was created over millions of years with deposition of ice and dust during different seasons.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Terra Cimmeria." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23613_hires.jpg" data-link="/spaceimages/details.php?id=PIA23613" data-thumbnail="/spaceimages/images/wallpaper/PIA23613-640x350.jpg" data-title="Terra Cimmeria - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 25, 2019</h3>
#  <div class="item_tease_overlay">Terra Cimmeria - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terra Cimmeria - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23613-640x350.jpg" title="Terra Cimmeria - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 25, 2019</div>
#  <div class="content_title">
#  										  Terra Cimmeria - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Terra Cimmeria.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows Bombala Crater. Located in Hesperia Planum, Bombala Crater is 38 km in diameter (23 miles)." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23612_hires.jpg" data-link="/spaceimages/details.php?id=PIA23612" data-thumbnail="/spaceimages/images/wallpaper/PIA23612-640x350.jpg" data-title="Bombala Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 24, 2019</h3>
#  <div class="item_tease_overlay">Bombala Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Bombala Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23612-640x350.jpg" title="Bombala Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 24, 2019</div>
#  <div class="content_title">
#  										  Bombala Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows Bombala Crater. Located in Hesperia Planum, Bombala Crater is 38 km in diameter (23 miles).
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Harris crater and an unnamed crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23611_hires.jpg" data-link="/spaceimages/details.php?id=PIA23611" data-thumbnail="/spaceimages/images/wallpaper/PIA23611-640x350.jpg" data-title="Harris Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 23, 2019</h3>
#  <div class="item_tease_overlay">Harris Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Harris Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23611-640x350.jpg" title="Harris Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 23, 2019</div>
#  <div class="content_title">
#  										  Harris Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Harris crater and an unnamed crater.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows most of the floor of an unnamed crater in southern Arabia Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23600_hires.jpg" data-link="/spaceimages/details.php?id=PIA23600" data-thumbnail="/spaceimages/images/wallpaper/PIA23600-640x350.jpg" data-title="Arabia Terra Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 20, 2019</h3>
#  <div class="item_tease_overlay">Arabia Terra Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Arabia Terra Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23600-640x350.jpg" title="Arabia Terra Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 20, 2019</div>
#  <div class="content_title">
#  										  Arabia Terra Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows most of the floor of an unnamed crater in southern Arabia Terra.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the floor of an unnamed crater in Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23599_hires.jpg" data-link="/spaceimages/details.php?id=PIA23599" data-thumbnail="/spaceimages/images/wallpaper/PIA23599-640x350.jpg" data-title="Terra Sabaea Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 19, 2019</h3>
#  <div class="item_tease_overlay">Terra Sabaea Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Terra Sabaea Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23599-640x350.jpg" title="Terra Sabaea Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 19, 2019</div>
#  <div class="content_title">
#  										  Terra Sabaea Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the floor of an unnamed crater in Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the inner rim, central peak ring and floor of Sagan Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23598_hires.jpg" data-link="/spaceimages/details.php?id=PIA23598" data-thumbnail="/spaceimages/images/wallpaper/PIA23598-640x350.jpg" data-title="Sagan Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 18, 2019</h3>
#  <div class="item_tease_overlay">Sagan Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Sagan Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23598-640x350.jpg" title="Sagan Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 18, 2019</div>
#  <div class="content_title">
#  										  Sagan Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the inner rim, central peak ring and floor of Sagan Crater.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This map of the Red Planet shows Jezero Crater, where NASAs Mars 2020 rover is scheduled to land in February 2021." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23518_hires.jpg" data-link="/spaceimages/details.php?id=PIA23518" data-thumbnail="/spaceimages/images/wallpaper/PIA23518-640x350.jpg" data-title="Map of NASA" landing="" mars="" s="" sites="">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 17, 2019</h3>
#  <div class="item_tease_overlay">Map of NASA's Mars Landing Sites</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Map of NASA" class="thumb" landing="" mars="" s="" sites="" src="/spaceimages/images/wallpaper/PIA23518-640x350.jpg" title="Map of NASA"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 17, 2019</div>
#  <div class="content_title">
#  										  Map of NASA's Mars Landing Sites
#  										</div>
#  <div class="article_teaser_body">
#  										  This map of the Red Planet shows Jezero Crater, where NASAs Mars 2020 rover is scheduled to land in February 2021.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the interior of Crommelin Crater." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23597_hires.jpg" data-link="/spaceimages/details.php?id=PIA23597" data-thumbnail="/spaceimages/images/wallpaper/PIA23597-640x350.jpg" data-title="Crommelin Crater - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 17, 2019</h3>
#  <div class="item_tease_overlay">Crommelin Crater - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Crommelin Crater - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23597-640x350.jpg" title="Crommelin Crater - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 17, 2019</div>
#  <div class="content_title">
#  										  Crommelin Crater - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the interior of Crommelin Crater.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a tributary channel that empties into the main Ares Vallis channel." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23596_hires.jpg" data-link="/spaceimages/details.php?id=PIA23596" data-thumbnail="/spaceimages/images/wallpaper/PIA23596-640x350.jpg" data-title="Ares Vallis Tributary - False Color">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 16, 2019</h3>
#  <div class="item_tease_overlay">Ares Vallis Tributary - False Color</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ares Vallis Tributary - False Color" class="thumb" src="/spaceimages/images/wallpaper/PIA23596-640x350.jpg" title="Ares Vallis Tributary - False Color"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 16, 2019</div>
#  <div class="content_title">
#  										  Ares Vallis Tributary - False Color
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a tributary channel that empties into the main Ares Vallis channel.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a field of dunes on the floor of an unnamed crater near Schiaparelli Crater in Noachis Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23580_hires.jpg" data-link="/spaceimages/details.php?id=PIA23580" data-thumbnail="/spaceimages/images/wallpaper/PIA23580-640x350.jpg" data-title="Crater Dunes">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 13, 2019</h3>
#  <div class="item_tease_overlay">Crater Dunes</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Crater Dunes" class="thumb" src="/spaceimages/images/wallpaper/PIA23580-640x350.jpg" title="Crater Dunes"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 13, 2019</div>
#  <div class="content_title">
#  										  Crater Dunes
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a field of dunes on the floor of an unnamed crater near Schiaparelli Crater in Noachis Terra.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23579_hires.jpg" data-link="/spaceimages/details.php?id=PIA23579" data-thumbnail="/spaceimages/images/wallpaper/PIA23579-640x350.jpg" data-title="Hephaestus Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 12, 2019</h3>
#  <div class="item_tease_overlay">Hephaestus Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hephaestus Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23579-640x350.jpg" title="Hephaestus Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 12, 2019</div>
#  <div class="content_title">
#  										  Hephaestus Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows the central portion of Hephaestus Fossae.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows huge regions of complex valleys and chaos, located in Xanthe and Margaritifer Terras." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23578_hires.jpg" data-link="/spaceimages/details.php?id=PIA23578" data-thumbnail="/spaceimages/images/wallpaper/PIA23578-640x350.jpg" data-title="Chryse Chaos">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 11, 2019</h3>
#  <div class="item_tease_overlay">Chryse Chaos</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Chryse Chaos" class="thumb" src="/spaceimages/images/wallpaper/PIA23578-640x350.jpg" title="Chryse Chaos"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 11, 2019</div>
#  <div class="content_title">
#  										  Chryse Chaos
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows huge regions of complex valleys and chaos, located in Xanthe and Margaritifer Terras.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="In this illustration, Mars holds near-surface water ice that would be easily accessible for astronauts to dig up. The water ice was identified as part of a map using data from NASA orbiters." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23515_hires.jpg" data-link="/spaceimages/details.php?id=PIA23515" data-thumbnail="/spaceimages/images/wallpaper/PIA23515-640x350.jpg" data-title="Water Ice Marked on Mars Globe (Illustration)">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 10, 2019</h3>
#  <div class="item_tease_overlay">Water Ice Marked on Mars Globe (Illustration)</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Water Ice Marked on Mars Globe (Illustration)" class="thumb" src="/spaceimages/images/wallpaper/PIA23515-640x350.jpg" title="Water Ice Marked on Mars Globe (Illustration)"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 10, 2019</div>
#  <div class="content_title">
#  										  Water Ice Marked on Mars Globe (Illustration)
#  										</div>
#  <div class="article_teaser_body">
#  										  In this illustration, Mars holds near-surface water ice that would be easily accessible for astronauts to dig up. The water ice was identified as part of a map using data from NASA orbiters.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This rainbow-colored map shows underground water ice on Mars." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23514_hires.jpg" data-link="/spaceimages/details.php?id=PIA23514" data-thumbnail="/spaceimages/images/wallpaper/PIA23514-640x350.jpg" data-title="A Water Ice Map for Mars">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 10, 2019</h3>
#  <div class="item_tease_overlay">A Water Ice Map for Mars</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="A Water Ice Map for Mars" class="thumb" src="/spaceimages/images/wallpaper/PIA23514-640x350.jpg" title="A Water Ice Map for Mars"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 10, 2019</div>
#  <div class="content_title">
#  										  A Water Ice Map for Mars
#  										</div>
#  <div class="article_teaser_body">
#  										  This rainbow-colored map shows underground water ice on Mars.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a large enclosed basin, located in Margaritifer Terra." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23577_hires.jpg" data-link="/spaceimages/details.php?id=PIA23577" data-thumbnail="/spaceimages/images/wallpaper/PIA23577-640x350.jpg" data-title="Margaritifer Terra">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 10, 2019</h3>
#  <div class="item_tease_overlay">Margaritifer Terra</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Margaritifer Terra" class="thumb" src="/spaceimages/images/wallpaper/PIA23577-640x350.jpg" title="Margaritifer Terra"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 10, 2019</div>
#  <div class="content_title">
#  										  Margaritifer Terra
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a large enclosed basin, located in Margaritifer Terra.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Medusa Fossae. Winds have eroded materials in this region, creating ridges and valleys aligned with the direction of the wind." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23576_hires.jpg" data-link="/spaceimages/details.php?id=PIA23576" data-thumbnail="/spaceimages/images/wallpaper/PIA23576-640x350.jpg" data-title="Medusae Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 9, 2019</h3>
#  <div class="item_tease_overlay">Medusae Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Medusae Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23576-640x350.jpg" title="Medusae Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 9, 2019</div>
#  <div class="content_title">
#  										  Medusae Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Medusa Fossae. Winds have eroded materials in this region, creating ridges and valleys aligned with the direction of the wind.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of the complex caldera at the summit of Ascraeus Mons." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23575_hires.jpg" data-link="/spaceimages/details.php?id=PIA23575" data-thumbnail="/spaceimages/images/wallpaper/PIA23575-640x350.jpg" data-title="Ascraeus Mons">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 6, 2019</h3>
#  <div class="item_tease_overlay">Ascraeus Mons</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Ascraeus Mons" class="thumb" src="/spaceimages/images/wallpaper/PIA23575-640x350.jpg" title="Ascraeus Mons"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 6, 2019</div>
#  <div class="content_title">
#  										  Ascraeus Mons
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of the complex caldera at the summit of Ascraeus Mons.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of Hypanis Valles." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23574_hires.jpg" data-link="/spaceimages/details.php?id=PIA23574" data-thumbnail="/spaceimages/images/wallpaper/PIA23574-640x350.jpg" data-title="Hypanis Valles">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 5, 2019</h3>
#  <div class="item_tease_overlay">Hypanis Valles</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Hypanis Valles" class="thumb" src="/spaceimages/images/wallpaper/PIA23574-640x350.jpg" title="Hypanis Valles"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 5, 2019</div>
#  <div class="content_title">
#  										  Hypanis Valles
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of Hypanis Valles.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Indus Vallis, located in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23573_hires.jpg" data-link="/spaceimages/details.php?id=PIA23573" data-thumbnail="/spaceimages/images/wallpaper/PIA23573-640x350.jpg" data-title="Indus Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 4, 2019</h3>
#  <div class="item_tease_overlay">Indus Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Indus Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23573-640x350.jpg" title="Indus Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 4, 2019</div>
#  <div class="content_title">
#  										  Indus Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Indus Vallis, located in northern Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Huo Hsing Valles, located in northern Terra Sabaea." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23572_hires.jpg" data-link="/spaceimages/details.php?id=PIA23572" data-thumbnail="/spaceimages/images/wallpaper/PIA23572-640x350.jpg" data-title="Huo Hsing Vallis">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 3, 2019</h3>
#  <div class="item_tease_overlay">Huo Hsing Vallis</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Huo Hsing Vallis" class="thumb" src="/spaceimages/images/wallpaper/PIA23572-640x350.jpg" title="Huo Hsing Vallis"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 3, 2019</div>
#  <div class="content_title">
#  										  Huo Hsing Vallis
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Huo Hsing Valles, located in northern Terra Sabaea.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows a section of one of the many channel forms found radial to the Elysium Mons volcanic complex." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23571_hires.jpg" data-link="/spaceimages/details.php?id=PIA23571" data-thumbnail="/spaceimages/images/wallpaper/PIA23571-640x350.jpg" data-title="Elysium Fossae">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">December 2, 2019</h3>
#  <div class="item_tease_overlay">Elysium Fossae</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Elysium Fossae" class="thumb" src="/spaceimages/images/wallpaper/PIA23571-640x350.jpg" title="Elysium Fossae"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">December 2, 2019</div>
#  <div class="content_title">
#  										  Elysium Fossae
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows a section of one of the many channel forms found radial to the Elysium Mons volcanic complex.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>, <li class="slide">
#  <a class="fancybox" data-description="This image from NASAs Mars Odyssey shows part of Maja Valles, a large channel system in Lunae Planum." data-fancybox-group="images" data-fancybox-href="/spaceimages/images/largesize/PIA23570_hires.jpg" data-link="/spaceimages/details.php?id=PIA23570" data-thumbnail="/spaceimages/images/wallpaper/PIA23570-640x350.jpg" data-title="Maja Valles Tributary">
#  <div class="image_and_description_container">
#  <div class="rollover_description">
#  <h3 class="release_date">November 29, 2019</h3>
#  <div class="item_tease_overlay">Maja Valles Tributary</div>
#  <div class="overlay_arrow">
#  <img alt="more arrow" src="/assets/images/overlay-arrow.png"/>
#  </div>
#  </div>
#  <div class="img">
#  <img alt="Maja Valles Tributary" class="thumb" src="/spaceimages/images/wallpaper/PIA23570-640x350.jpg" title="Maja Valles Tributary"/>
#  </div>
#  <div class="list_text_content">
#  <div class="article_teaser_body">November 29, 2019</div>
#  <div class="content_title">
#  										  Maja Valles Tributary
#  										</div>
#  <div class="article_teaser_body">
#  										  This image from NASAs Mars Odyssey shows part of Maja Valles, a large channel system in Lunae Planum.
#  										</div>
#  </div>
#  </div>
#  </a>
#  </li>]

# %%
table=soup.find('div',class_='grid_layout')
rows = table.find_all('li')
for row in rows[0:]:
    img_dict={}
    cells=row.find('div', class_='img')
    print(cells)
    
    #for i, cell in enumerate(cells):
    #    print(cell.text.strip())
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
