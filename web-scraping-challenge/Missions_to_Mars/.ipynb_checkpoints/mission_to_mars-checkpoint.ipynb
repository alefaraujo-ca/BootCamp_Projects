# %%
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
import pandas as pd

# %%
executable_path={'executable_path':'chromedriver.exe'}

browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# # NASA Mars News

# %%
url = 'https://mars.nasa.gov/news/?page=0&per_page=40&order=publish_date+desc%2Ccreated_at+desc&search=&category=19%2C165%2C184%2C204&blank_scope=Latest'
browser.visit(url)

# %%
html = browser.html
soup = bs(html, 'lxml')
table=soup.find('div', class_='grid_layout')
rows=table.find_all('li')

# %%
pre_df=[]
columns=['date', 'title', 'content']

# %%
for row in rows[0:]:
    news_dict={}
    cells=row.find('div', class_="list_text")

    for i, cell in enumerate(cells):
        news_dict[columns[i]]=cell.text.strip()
        #print(i, cell.text.strip())
        if i==2:
            pre_df.append(news_dict)

df_news_nasa=pd.DataFrame(pre_df, columns=columns)

# %%
df_news_nasa
# Out:
#                   date                                              title  \
# 0    December 27, 2019     Media Get a Close-Up of NASA's Mars 2020 Rover
# 1    December 23, 2019   Space History Is Made in This NASA Robot Factory
# 2    December 18, 2019   NASA's Mars 2020 Rover Completes Its First Drive
# 3    December 10, 2019          NASA's Treasure Map for Water Ice on Mars
# 4    December 10, 2019  Two Rovers to Roll on Mars Again: Curiosity an...
# 5    November 27, 2019  NASA's Briefcase-Size MarCO Satellite Picks Up...
# 6    November 26, 2019  Global Storms on Mars Launch Dust Towers Into ...
# 7    November 21, 2019  NASA Updates Mars 2020 Mission Environmental R...
# 8    November 20, 2019       Two of a Space Kind: Apollo 12 and Mars 2020
# 9    November 15, 2019  Mars Scientists Investigate Ancient Life in Au...
# 10   November 12, 2019  NASA's Mars 2020 Will Hunt for Microscopic Fos...
# 11   November 12, 2019  With Mars Methane Mystery Unsolved, Curiosity ...
# 12   November  7, 2019       NASA's Mars 2020 Heads Into the Test Chamber
# 13   November  7, 2019  Screening Soon: 'The Pathfinders' Trains Lens ...
# 14   November  6, 2019           InSight's 'Mole' Team Peers into the Pit
# 15   November  6, 2019            Common Questions about InSight's 'Mole'
# 16    October 24, 2019             Mars 2020 Stands on Its Own Six Wheels
# 17    October 24, 2019       New Selfie Shows Curiosity, the Mars Chemist
# 18    October 22, 2019      Naming a NASA Mars Rover Can Change Your Life
# 19    October 18, 2019     Mars 2020 Unwrapped and Ready for More Testing
# 20    October 16, 2019  HiRISE Views NASA's InSight and Curiosity on Mars
# 21    October  7, 2019  NASA's Curiosity Rover Finds an Ancient Oasis ...
# 22    October  4, 2019  NASA's Mars 2020 Rover Tests Descent-Stage Sep...
# 23    October  3, 2019  NASA's Push to Save the Mars InSight Lander's ...
# 24    October  1, 2019     NASA's InSight 'Hears' Peculiar Sounds on Mars
# 25  September 23, 2019  NASA Mars Mission Connects With Bosnian and He...
# 26  September 18, 2019  Deadline Closing for Names to Fly on NASA's Ne...
# 27  September 16, 2019  NASA Wins Two Emmy Awards for Interactive Miss...
# 28  September 12, 2019                 NASA's Mars 2020 Comes Full Circle
# 29     August 28, 2019      NASA Invites Students to Name Mars 2020 Rover
# 30     August 28, 2019  NASA's Mars Helicopter Attached to Mars 2020 R...
# 31     August 23, 2019  What's Mars Solar Conjunction, and Why Does It...
# 32     August 23, 2019     Scientists Explore Outback as Testbed for Mars
# 33     August 22, 2019       NASA-JPL Names 'Rolling Stones Rock' on Mars
# 34     August 15, 2019    Robotic Toolkit Added to NASA's Mars 2020 Rover
# 35     August 13, 2019  Space Samples Link NASA's Apollo 11 and Mars 2020
# 36     August  9, 2019                Small Satellite Mission of the Year
# 37     August  5, 2019  NASA 'Optometrists' Verify Mars 2020 Rover's 2...
# 38     August  5, 2019  New Finds for Mars Rover, Seven Years After La...
# 39     August  3, 2019  MEDLI2 Installation on Mars 2020 Aeroshell Begins
#
#                                               content
# 0   The clean room at NASA's Jet Propulsion Labora...
# 1   From rockets to rovers, JPL's Spacecraft Assem...
# 2   In a 10-plus-hour marathon, the rover steered,...
# 3   A new study identifies frozen water just below...
# 4   They look like twins. But under the hood, the ...
# 5   The twin spacecraft, the first of their kind t...
# 6   A Mars Dust Tower Stands Out Dust storms are c...
# 7   NASA and the Department of Energy have complet...
# 8   Apollo 12 and the upcoming Mars 2020 mission m...
# 9   Teams with NASA's Mars 2020 and ESA's ExoMars ...
# 10  A new paper identifies a ring of minerals at t...
# 11  For the first time in the history of space exp...
# 12  In this time-lapse video taken at JPL, enginee...
# 13  With the Mars 2020 mission ramping up, the doc...
# 14           Efforts to save the heat probe continue.
# 15  There's a new plan to get InSight's "mole" mov...
# 16  In time-lapse video, taken at JPL, captures th...
# 17  The NASA rover performed a special chemistry e...
# 18  Want to name the robotic scientist NASA is sen...
# 19  In time-lapse video, bunny-suited engineers re...
# 20  New images taken from space offer the clearest...
# 21  New evidence suggests salty, shallow ponds onc...
# 22  A crane lifts the rocket-powered descent stage...
# 23  The scoop on the end of the spacecraft's robot...
# 24  Listen to the marsquakes and other, less-expec...
# 25  A letter from NASA was presented to the mayor ...
# 26  You have until Sept. 30 to send your names to ...
# 27  NASA-JPL's coverage of the Mars InSight landin...
# 28  Aiming to pinpoint the Martian vehicle's cente...
# 29  Through Nov. 1, K-12 students in the U.S. are ...
# 30  The helicopter will be first aircraft to perfo...
# 31  NASA spacecraft at Mars are going to be on the...
# 32  Australia provides a great place for NASA's Ma...
# 33  NASA's Mars InSight mission honored one of the...
# 34  The bit carousel, which lies at the heart of t...
# 35  While separated by half a century, NASA's Apol...
# 36  The first interplanetary CubeSats were recogni...
# 37  Mars 2020 rover underwent an eye exam after se...
# 38  NASA's Curiosity rover is discovering odd rock...
# 39  Hardware installed onto NASA's Mars 2020 entry...

# %% [markdown]
# # JPL Mars Space Images - Featured Image

# %%
url='https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(url)
html = browser.html
soup = bs(html, 'lxml')

# %%
image = soup.find("img", class_="thumb")["src"]
print(image)
# Out:
# /spaceimages/images/wallpaper/PIA23634-640x350.jpg

# %% [markdown]
# # Mars Weather

# %%
url = 'https://twitter.com/marswxreport?lang=en'
browser.visit(url)
html = browser.html
soup = bs(html,'lxml')

# %%
mars_weather = soup.find('p', class_='TweetTextSize TweetTextSize--normal js-tweet-text tweet-text').text
print(mars_weather)
# Out:
# High altitude notilucent clouds above Mars on sol 2410 via @MarsCuriosity  NavCam Credit NASA/JPL/Justin Cowartpic.twitter.com/4P1cueZR92

# %% [markdown]
# # Mars Facts

# %%
# Scrape the table of Mars facts
url = 'https://space-facts.com/mars/'
tables = pd.read_html(url)
df_profile = tables[0]
df_profile.columns = ['Aspect', 'Value']
df_profile
# Out:
#                  Aspect                          Value
# 0  Equatorial Diameter:                       6,792 km
# 1       Polar Diameter:                       6,752 km
# 2                 Mass:  6.39 × 10^23 kg (0.11 Earths)
# 3                Moons:            2 (Phobos & Deimos)
# 4       Orbit Distance:       227,943,824 km (1.38 AU)
# 5         Orbit Period:           687 days (1.9 years)
# 6  Surface Temperature:                   -87 to -5 °C
# 7         First Record:              2nd millennium BC
# 8          Recorded By:           Egyptian astronomers

# %%
# Convert to HTML table string
df_profile.to_html('mars_profile.html')

# %% [markdown]
# # Mars Hemispheres

# %%
url = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'
browser.visit(url)
html = browser.html
soup = bs(html, 'lxml')

# %%
mars_hemispheres = []
links = soup.find_all('h3')

for link in links:
    #print(hemi.text)
    mars_hemispheres.append(link.text)

mars_hemispheres
# Out:
# ['Cerberus Hemisphere Enhanced',
#  'Schiaparelli Hemisphere Enhanced',
#  'Syrtis Major Hemisphere Enhanced',
#  'Valles Marineris Hemisphere Enhanced']

# %%
hemisphere_image_urls = []
data = {}

for link in mars_hemispheres:
    
    data['title'] = link

    browser.click_link_by_partial_text(link)
    data['image_url'] = browser.find_by_text('Sample')['href']

    hemisphere_image_urls.append(data)
    
    browser.back()
    
print(hemisphere_image_urls)
# Out:
# Cerberus Hemisphere Enhanced
# http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/cerberus_enhanced.tif/full.jpg
# Schiaparelli Hemisphere Enhanced
# http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/schiaparelli_enhanced.tif/full.jpg
# Syrtis Major Hemisphere Enhanced
# http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/syrtis_major_enhanced.tif/full.jpg
# Valles Marineris Hemisphere Enhanced
# http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg
# [{'title': 'Valles Marineris Hemisphere Enhanced', 'image_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}, {'title': 'Valles Marineris Hemisphere Enhanced', 'image_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}, {'title': 'Valles Marineris Hemisphere Enhanced', 'image_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}, {'title': 'Valles Marineris Hemisphere Enhanced', 'image_url': 'http://astropedia.astrogeology.usgs.gov/download/Mars/Viking/valles_marineris_enhanced.tif/full.jpg'}]
